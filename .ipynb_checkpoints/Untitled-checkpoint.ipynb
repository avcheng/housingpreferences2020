# %%
import csv
import matplotlib
import pandas as pd

# %%
df = pd.read_csv('housing_prefs.csv')
df
# Out:
#     Please ONLY fill out this survey if you are a current freshman.  \
# 0                I am currently a freshman at Harvard.
# 1                I am currently a freshman at Harvard.
# 2                I am currently a freshman at Harvard.
# 3                I am currently a freshman at Harvard.
# 4                I am currently a freshman at Harvard.
# 5                I am currently a freshman at Harvard.
# 6                I am currently a freshman at Harvard.
# 7                I am currently a freshman at Harvard.
# 8                I am currently a freshman at Harvard.
# 9                I am currently a freshman at Harvard.
# 10               I am currently a freshman at Harvard.
# 11               I am currently a freshman at Harvard.
# 12               I am currently a freshman at Harvard.
# 13               I am currently a freshman at Harvard.
# 14               I am currently a freshman at Harvard.
# 15               I am currently a freshman at Harvard.
# ...

# %%
for column in df:
   # Select column contents by column name using [] operator
   columnSeriesObj = df[column]

   print('Colunm Name : ', column)
   print('Column Contents : ', columnSeriesObj.mean)
# Out:
# Blocking group size    6.043956
# Adams                  4.736264
# Cabot                  9.824176
# Currier                9.402930
# Dunster                5.175824
# Eliot                  5.890110
# Kirkland               8.183150
# Leverett               6.842491
# Lowell                 2.578755
# Mather                 7.307692
# Pfoho                  9.483516
# Quincy                 5.139194
# Winthrop               3.435897
# dtype: float64
